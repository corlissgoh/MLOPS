# %% [markdown]
# # MLOps con MLflow

# %% [markdown]
# #### Get data

# %%
import mlflow

mlflow.set_tracking_uri("http://localhost:5000")

# load the dataset from pycaret
from pycaret.datasets import get_data
data = get_data('diamond')
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %% [markdown]
# #### Preprocessing

# %%
# initialize setup
from pycaret.regression import *
s = setup(data, target = 'Price', 
          transform_target = True, 
          log_experiment = True, 
          #log_plots = True,
          experiment_name = 'diamond')
# Out:
# <style type="text/css">
# #T_e6495_row10_col1, #T_e6495_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e6495">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e6495_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e6495_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e6495_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e6495_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e6495_row0_col1" class="data row0 col1" >4342</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e6495_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e6495_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e6495_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_e6495_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e6495_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_e6495_row3_col1" class="data row3 col1" >(6000, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_e6495_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_e6495_row4_col1" class="data row4 col1" >(6000, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_e6495_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_e6495_row5_col1" class="data row5 col1" >(4200, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_e6495_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_e6495_row6_col1" class="data row6 col1" >(1800, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_e6495_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_e6495_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_e6495_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_e6495_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_e6495_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_e6495_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_e6495_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_e6495_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_e6495_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_e6495_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_e6495_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_e6495_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_e6495_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_e6495_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_e6495_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_e6495_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_e6495_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_e6495_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_e6495_row16_col0" class="data row16 col0" >Transform target</td>
#       <td id="T_e6495_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_e6495_row17_col0" class="data row17 col0" >Transform target method</td>
#       <td id="T_e6495_row17_col1" class="data row17 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_e6495_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_e6495_row18_col1" class="data row18 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_e6495_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_e6495_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_e6495_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_e6495_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_e6495_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_e6495_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_e6495_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_e6495_row22_col1" class="data row22 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_e6495_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_e6495_row23_col1" class="data row23 col1" >diamond</td>
#     </tr>
#     <tr>
#       <th id="T_e6495_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_e6495_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_e6495_row24_col1" class="data row24 col1" >a0b3</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Model Training

# %%
# compare all models
best = compare_models()
# Out:
# <style type="text/css">
# #T_00a13 th {
#   text-align: left;
# }
# #T_00a13_row0_col0, #T_00a13_row1_col0, #T_00a13_row1_col1, #T_00a13_row1_col2, #T_00a13_row1_col3, #T_00a13_row1_col4, #T_00a13_row1_col5, #T_00a13_row1_col6, #T_00a13_row2_col0, #T_00a13_row2_col1, #T_00a13_row2_col2, #T_00a13_row2_col3, #T_00a13_row2_col4, #T_00a13_row2_col5, #T_00a13_row2_col6, #T_00a13_row3_col0, #T_00a13_row3_col1, #T_00a13_row3_col2, #T_00a13_row3_col3, #T_00a13_row3_col4, #T_00a13_row3_col5, #T_00a13_row3_col6, #T_00a13_row4_col0, #T_00a13_row4_col1, #T_00a13_row4_col2, #T_00a13_row4_col3, #T_00a13_row4_col4, #T_00a13_row4_col5,
>0.1170</td>
#     </tr>
#     <tr>
#       <th id="T_00a13_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_00a13_row5_col0" class="data row5 col0" >Decision Tree Regressor</td>
#       <td id="T_00a13_row5_col1" class="data row5 col1" >946.1960</td>
#       <td id="T_00a13_row5_col2" class="data row5 col2" >3526660.6245</td>
#       <td id="T_00a13_row5_col3" class="data row5 col3" >1855.8197</td>
#       <td id="T_00a13_row5_col4" class="data row5 col4" >0.9672</td>
#       <td id="T_00a13_row5_col5" class="data row5 col5" >0.1020</td>
#       <td id="T_00a13_row5_col6" class="data row5 col6" >0.0750</td>
#       <td id="T_00a13_row5_col7" class="data row5 col7" >0.0490</td>
#     </tr>
#     <tr>
#       <th id="T_00a13_level0_row6" class="row_heading level0 row6" >ada</th>
#       <td id="T_00a13_row6_col0" class="data row6

# %%
# check the residuals of trained model
plot_model(best, plot = 'residuals')

# %%
# check feature importance
plot_model(best, plot = 'feature')

# %%
# finalize the model
final_best = finalize_model(best)

# save model to disk
save_model(final_best, 'diamond-pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('target_transformation',
#                   TransformerWrapperWithInverse(transformer=TargetTransformer(estimator=PowerTransformer(standardize=False)))),
#                  ('numerical_imputer',
#                   TransformerWrapper(include=['Carat Weight'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['Cut', 'Color', 'Clarity',
#                                               'P...
#                   TransformerWrapper(include=['Cut', 'Color', 'Clarity',
#                                               'Polish', 'Symmetry'],
#                                      transformer=OneHotEncoder(cols=['Cut',
#                                                                      'Color',
#                                                                      'Clarity',
#                                                                      'Polish',
#                                                                      'Symmetry'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('actual_estimator',
#                   <catboost.core.CatBoostRegressor object at 0x0000022E379D5C50>)]),
#  'diamond-pipeline.pkl')

# %% [markdown]
# ### Model management with MLFlow

# %%
# within notebook (notice ! sign infront)
# !mlflow ui
# Out:
# ^C

# %%
#localhost:5000

# %% [markdown]
# ### Consume the model

# %%
import mlflow
logged_model = 'runs:/9ce0981cbd0c48ac9ae9a011e55bd870/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

# Predict on a Pandas DataFrame.
import pandas as pd
loaded_model.predict(pd.DataFrame(data))
# Out:
# 0        5328.967106
# 1        3454.281120
# 2        3227.932338
# 3        4462.754787
# 4        3293.268483
#             ...
# 5995     6362.718820
# 5996     5660.671360
# 5997     6283.563997
# 5998    11071.296867
# 5999    35504.199090
# Name: Price, Length: 6000, dtype: float64

# %%
# print pipeline
print(loaded_model)
pipeline = loaded_model
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: model
#   flavor: mlflow.sklearn
#   run_id: 9ce0981cbd0c48ac9ae9a011e55bd870

# %%
# alternative if you are saving your artifact locally

pipeline = load_model('diamond-pipeline')

pipeline = loaded_model
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
# print pipeline
print(pipeline)
# Out:
# mlflow.pyfunc.loaded_model:
#   artifact_path: model
#   flavor: mlflow.sklearn
#   run_id: 9ce0981cbd0c48ac9ae9a011e55bd870

# %%
# create a copy of data and drop Price
data2 = data.copy()
//data2.drop('Price', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# SyntaxError                               Traceback (most recent call last)
# File D:\ProgramData\anaconda3\envs\mlops\Lib\site-packages\IPython\core\compilerop.py:86, in CachingCompiler.ast_parse(self, source, filename, symbol)
#      81 def ast_parse(self, source, filename='<unknown>', symbol='exec'):
#      82     """Parse code to an AST with the current compiler flags active.
#      83
#      84     Arguments are exactly the same as ast.parse (in the standard library),
#      85     and are passed to the built-in compile function."""
# ---> 86     return compile(source, filename, symbol, self.flags | PyCF_ONLY_AST, 1)
#
# SyntaxError: invalid syntax (1303203642.py, line 3)

# %%
# generate predictions
from pycaret.regression import predict_model
predictions = predict_model(pipeline, data=data2)
predictions.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 3
#       1 # generate predictions
#       2 from pycaret.regression import predict_model
# ----> 3 predictions = predict_model(pipeline, data=data2)
#       4 predictions.head()
#
# File D:\ProgramData\anaconda3\envs\mlops\Lib\site-packages\pycaret\regression\functional.py:1895, in predict_model(estimator, data, round, verbose)
#    1892 if experiment is None:
#    1893     experiment = _EXPERIMENT_CLASS()
# -> 1895 return experiment.predict_model(
#    1896     estimator=estimator,
#    1897     data=data,
#    1898     round=round,
#    1899     verbose=verbose,
#    1900 )
#
# File D:\ProgramData\anaconda3\envs\mlops\Lib\site-packages\pycaret\regression\oop.py:2188, in RegressionExperiment.predict_model(self, estimator, data, round, verbose)
#    2134 def predict_model(
#    2135     self,
#    2136     estimator,
#    (...)
#    2139     verbose: bool = True,
#    2140 ) -> pd.DataFrame:
#    2141     """
#    2142     This function predicts ``Label`` using a trained model. When ``data`` is
#    2143     None, it predicts label on the holdout set.
#    (...)
#    2185
#    2186     """
# -> 2188     return super().predict_model(
#    2189         estimator=estimator,
#    2190         data=data,
#    2191         probability_threshold=None,
#    2192         encoded_labels=False,
#    2193         round=round,
#    2194         verbose=verbose,
#    2195     )
#
# File D:\ProgramData\anaconda3\envs\mlops\Lib\site-packages\pycaret\internal\pycaret_experiment\supervised_experiment.py:4984, in _SupervisedExperiment.predict_model(self, estimator, data, probability_threshold, encoded_labels, raw_score, round, verbose, ml_usecase, preprocess)
#    4981         probability_threshold = estimator.probability_threshold
#    4982     estimator = get_estimator_from_meta_estimator(estimator)
# -> 4984 pred = np.nan_to_num(estimator.predict(X_test_))
#    4985 pred = pipeline.inverse_transform(pred)
#    4986 # Need to convert labels back to numbers
#    4987 # TODO optimize
#
# File D:\ProgramData\anaconda3\envs\mlops\Lib\site-packages\mlflow\pyfunc\__init__.py:381, in PyFuncModel.predict(self, data)
#     379 if input_schema is not None:
#     380     data = _enforce_schema(data, input_schema)
# --> 381 return self._predict_fn(data)
#
# File D:\ProgramData\anaconda3\envs\mlops\Lib\site-packages\pycaret\internal\pipeline.py:325, in Pipeline.predict(self, X, **predict_params)
#     323 @available_if(_final_estimator_has("predict"))
#     324 def predict(self, X, **predict_params):
# --> 325     X, _ = self._memory_full_transform(self, X, None, with_final=False)
#     327     y = self.steps[-1][-1].predict(X, **predict_params)
#     328     y = self.inverse_transform(y)
#
# File D:\ProgramData\anaconda3\envs\mlops\Lib\site-packages\joblib\memory.py:353, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     352 def __call__(self, *args, **kwargs):
# --> 353     return self.func(*args, **kwargs)
#
# File D:\ProgramData\anaconda3\envs\mlops\Lib\site-packages\pycaret\internal\pipeline.py:110, in _full_transform(pipeline, X, y, **kwargs)
#     108 def _full_transform(pipeline: "Pipeline", X, y, **kwargs):
#     109     for _, _, transformer in pipeline._iter(**kwargs):
# --> 110         X, y = pipeline._memory_transform(transformer, X, y)
#     111     return X, y
#
# File D:\ProgramData\anaconda3\envs\mlops\Lib\site-packages\joblib\memory.py:353, in NotMemorizedFunc.__call__(self, *args, **kwargs)
#     352 def __call__(self, *args, **kwargs):
# --> 353     return self.func(*args, **kwargs)
#
# File D:\ProgramData\anaconda3\envs\mlops\Lib\site-packages\pycaret\internal\pipeline.py:79, in _transform_one(transformer, X, y)
#      77 if "y" in signature(transformer.transform).parameters:
#      78     args.append(y)
# ---> 79 output = transformer.transform(*args)
#      81 if isinstance(output, tuple):
#      82     X, y = output[0], output[1]
#
# File D:\ProgramData\anaconda3\envs\mlops\Lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File D:\ProgramData\anaconda3\envs\mlops\Lib\site-packages\pycaret\internal\preprocess\transformers.py:248, in TransformerWrapper.transform(self, X, y)
#     246     else:
#     247         return variable_return(X, y)
# --> 248     args.append(X[self._include])
#     249 if "y" in transform_params:
#     250     if y is not None:
#
# File D:\ProgramData\anaconda3\envs\mlops\Lib\site-packages\pandas\core\frame.py:3813, in DataFrame.__getitem__(self, key)
#    3811     if is_iterator(key):
#    3812         key = list(key)
# -> 3813     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3815 # take() does not accept boolean indexers
#    3816 if getattr(indexer, "dtype", None) == bool:
#
# File D:\ProgramData\anaconda3\envs\mlops\Lib\site-packages\pandas\core\indexes\base.py:6070, in Index._get_indexer_strict(self, key, axis_name)
#    6067 else:
#    6068     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6070 self._raise_if_missing(keyarr, indexer, axis_name)
#    6072 keyarr = self.take(indexer)
#    6073 if isinstance(key, Index):
#    6074     # GH 42790 - Preserve name from an Index
#
# File D:\ProgramData\anaconda3\envs\mlops\Lib\site-packages\pandas\core\indexes\base.py:6133, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6130     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6132 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6133 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['Cut', 'Color', 'Clarity', 'Polish', 'Symmetry'] not in index"

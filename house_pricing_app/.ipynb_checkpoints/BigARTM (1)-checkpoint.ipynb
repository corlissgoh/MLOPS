# %% [markdown]
# # BigARTM
#
# Topic modeling is a type of statistical modeling for discovering the abstract “topics” in a collection of documents. LDA (Latent Dirichlet Allocation) is one of the most popular and widely used tools for that. **BigARTM** is a tool to infer topic models, based on a novel technique called <em>**Additive Regularization of Topic Models**</em>. This technique effectively builds multi-objective models by adding the weighted sums of regularizers to the optimization criterion. BigARTM is known to combine well very different objectives, including sparsing, smoothing, topics decorrelation and many others. Such combinations of regularizers significantly improves several quality measures at once almost without any loss of the perplexity.
#
# The pip installation for BigARTM is only available for linux, hence for this practical we will execute it using Google Colab. For windows installation you can refer to this guide: https://bigartm.readthedocs.io/en/stable/installation/windows.html
#
# Install the following library:
# > pip install bigartm

# %%
"""
Run this command. This will clone/download the necessary jupyter notebook and data files required
"""

# !git clone https://github.com/limaih/bigartm
# Out:
# Cloning into 'bigartm'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (28/28), done.
# remote: Total 30 (delta 7), reused 2 (delta 0), pack-reused 0
# Receiving objects: 100% (30/30), 8.57 MiB | 5.09 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
pip install bigartm
# Out:
# Collecting bigartm
#   Downloading bigartm-0.9.2-cp310-cp310-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 25.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from bigartm) (1.5.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bigartm) (1.23.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from bigartm) (4.66.1)
# Requirement already satisfied: protobuf>=3.0 in /usr/local/lib/python3.10/dist-packages (from bigartm) (3.20.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->bigartm) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->bigartm) (2023.3.post1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->bigartm) (1.16.0)
# Installing collected packages: bigartm
# Successfully installed bigartm-0.9.2

# %% [markdown]
# ## Import libraries and load dataset
# For this practical we will use the NIPS papers. You can find the full dataset from kaggle: https://www.kaggle.com/datasets/benhamner/nips-papers?select=papers.csv
#
# The practical below is built using NIPS papers in 2017. Try out using the full dataset. Upload the papers.csv file to colab session storage and change the codes below to use the full dataset.
#
# ~~~Python
# import pandas as pd
#
# df = pd.read_csv('bigartm/papers2017.csv')
# all_texts = df['paper_text']
# all_texts.head()
# ~~~

# %%
import pandas as pd

df = pd.read_csv('bigartm/papers2017.csv')
all_texts = df['paper_text']
all_texts.head()
# Out:
# 0    Wider and Deeper, Cheaper and Faster:\nTensori...
# 1    Concentration of Multilinear Functions of the ...
# 2    Deep Subspace Clustering Networks\n\nPan Ji?\n...
# 3    Attentional Pooling for Action Recognition\n\n...
# 4    On the Consistency of Quick Shift\n\nHeinrich ...
# Name: paper_text, dtype: object

# %%
df.head(2)
# Out:
#    Unnamed: 0                                              title  \
# 0        6197  Wider and Deeper, Cheaper and Faster: Tensoriz...
# 1        6198  Concentration of Multilinear Functions of the ...
#
#                                           paper_text
# 0  Wider and Deeper, Cheaper and Faster:\nTensori...
# 1  Concentration of Multilinear Functions of the ...

# %% [markdown]
# ## Data Preprocessing
# We will begin with data preprocessing with the following pipeline:
# 1. lowercase
# 2. remove punctuation
# 3. lemmatizing
# 4. remove stopwords
# 5. remove short words & digits
#
# ![data_pipeline.png](data:image/png;base64,...)
#
# ~~~Python
# from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS as esw
# from nltk.stem import WordNetLemmatizer, PorterStemmer
# from nltk import word_tokenize
#
# import string
# import nltk
# nltk.download('punkt')
# nltk.download('wordnet')
# nltk.download('omw-1.4')
#
# lemmatizer=WordNetLemmatizer()
#
# ps = PorterStemmer()
# cachedStopWords = ["fig", "figure", "et", "al", "table", "data", "analysis", "analyze", "study", "method", "result",
#                    "conclusion", "author", "find", "found", "show", "perform", "demonstrate", "evaluate", "discuss",
#                    "google", "scholar", "pubmed", "web", "science", "crossref", "supplementary", "(fig.)", "(figure",
#                    "fig.", "al.", "did", "thus,", "…", "" "", "interestingly", "and/or", "author"] + list(esw)
#
# def lemmatize_article(sentence):
#     sentence = word_tokenize(sentence)
#     res = ''
#     for word in sentence:
#         word = lemmatizer.lemmatize(word)
#         res += word + ' '
#     return res
#
# def remove_stop_words(sentence):
#     return ' '.join([word for word in sentence.split() if word not in cachedStopWords])
#
# def remove_short(sentence):
#     return ' '.join([word for word in sentence.split() if len(word) >= 3])
#
# def remove_digits(sentence):
#     return ' '.join([i for i in sentence.split() if not i.isdigit()])
#
# def preprocess(all_texts):
#     all_texts = list(map(lambda x: x.lower(), all_texts))
#     all_texts = list(map(lambda x: x.translate(str.maketrans('', '', string.punctuation)), all_texts))
#     all_texts = list(map(lambda x: lemmatize_article(x), all_texts))
#     all_texts = list(map(lambda x: x.strip(), all_texts))
#     all_texts = list(map(lambda x: remove_stop_words(x), all_texts))
#     all_texts = list(map(lambda x: remove_short(x), all_texts))
#     all_texts = list(map(lambda x: remove_digits(x), all_texts))
#     return all_texts
#
# all_texts = preprocess(all_texts)
# all_texts[0]
# ~~~

# %%
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS as esw
from nltk.stem import WordNetLemmatizer, PorterStemmer
from nltk import word_tokenize

import string
import nltk
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')

lemmatizer=WordNetLemmatizer()

ps = PorterStemmer()
cachedStopWords = ["fig", "figure", "et", "al", "table", "data", "analysis", "analyze", "study", "method", "result",
                   "conclusion", "author", "find", "found", "show", "perform", "demonstrate", "evaluate", "discuss",
                   "google", "scholar", "pubmed", "web", "science", "crossref", "supplementary", "(fig.)", "(figure",
                   "fig.", "al.", "did", "thus,", "…", "" "", "interestingly", "and/or", "author"] + list(esw)

def lemmatize_article(sentence):
    sentence = word_tokenize(sentence)
    res = ''
    for word in sentence:
        word = lemmatizer.lemmatize(word)
        res += word + ' '
    return res

def remove_stop_words(sentence):
    return ' '.join([word for word in sentence.split() if word not in cachedStopWords])

def remove_short(sentence):
    return ' '.join([word for word in sentence.split() if len(word) >= 3])

def remove_digits(sentence):
    return ' '.join([i for i in sentence.split() if not i.isdigit()])

def preprocess(all_texts):
    all_texts = list(map(lambda x: x.lower(), all_texts))
    all_texts = list(map(lambda x: x.translate(str.maketrans('', '', string.punctuation)), all_texts))
    all_texts = list(map(lambda x: lemmatize_article(x), all_texts))
    all_texts = list(map(lambda x: x.strip(), all_texts))
    all_texts = list(map(lambda x: remove_stop_words(x), all_texts))
    all_texts = list(map(lambda x: remove_short(x), all_texts))
    all_texts = list(map(lambda x: remove_digits(x), all_texts))
    return all_texts

all_texts = preprocess(all_texts)
all_texts[0]
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# 'wider deeper cheaper faster tensorized lstms sequence learning zhen he12 shaobing gao3 liang xiao2 daxue liu2 hangen he2 david barber14 university college london national university defense technology sichuan university alan turing institute abstract long shortterm memory lstm popular approach boosting ability recurrent neural network store longer term temporal information capacity lstm network increased widening adding layer usually introduces additional parameter increase runtime alternative propose tensorized lstm hidden state represented tensor updated crosslayer convolution increasing tensor size network widened efficiently additional parameter parameter shared different location tensor delaying output network deepened implicitly little additional runtime deep computation timestep merged temporal computation sequence experiment conducted challenging sequence learning task potential proposed model introduction consider timeseries prediction task producing desired output timestep given observed input sequence x1t vectors1 recurrent neural network rnn powerful model learns use hidden state vector encapsulate relevant feature entire input history x1t timestep let hcat concatenation current input previous hidden state ht1 hcat ht1 update hidden state defined hcat rrm weight bias hidden activation elementwise tanh function finally output timestep generated differentiable function depending task vanilla rnn difficulty modeling longrange dependency vanishingexploding gradient problem long shortterm memory lstms alleviate corresponding shaobing gao gaoshaobingscueducn zhen hezhencsgmailcom vector assumed row form paper 31st conference neural information processing nip long beach usa problem employing memory cell preserve information longer adopting gating mechanism modulate information flow given success lstm sequence modeling natural consider increase complexity model increase set task lstm profitably applied consider capacity network consist component width information handled parallel depth number computation step naive way widen lstm increase number unit hidden layer parameter number scale quadratically number unit deepen lstm popular stacked lstm slstm stack multiple lstm layer runtime proportional number layer information input potentially lost gradient vanishingexplosion propagates vertically layer paper introduce way widen deepen lstm whilst keeping parameter number runtime largely unchanged summary make following contribution tensorize rnn hidden state vector higherdimensional tensor allow flexible parameter sharing widened efficiently additional parameter based merge rnn deep computation temporal computation network deepened little additional runtime resulting tensorized rnn trnn extend trnn lstm tensorized lstm tlstm integrates novel memory cell convolution help prevent vanishingexploding gradient tensorizing hidden state seen rnn parameter number scale quadratically size hidden state popular way limit parameter number widening network organize parameter higherdimensional tensor factorized lowerrank subtensors contain significantly fewer element known tensor factorization implicitly widens network hidden state vector fact broadcast interact tensorized parameter common way reduce parameter number share small set parameter different location hidden state similar convolutional neural network cnns adopt parameter sharing cutdown parameter number rnns compared factorization following advantage scalability number shared parameter set independent hidden state size separability information flow carefully managed controlling receptive field allowing shift rnn deep computation temporal domain sec explicitly tensorize rnn hidden state vector compared vector tensor better flexibility specify dimension share parameter just increase size dimension introducing additional parameter efficiency higherdimensional tensor network widened faster wrt depth fixing parameter number sec ease exposition consider tensor matrix tensorize hidden st ...

# %% [markdown]
# ## Extract ngrams
# Now we are ready to tokenize the sentences, obtain a bag of words and perform topic modeling. n-grams are sometimes very useful for this purpose. They help to extract well-established expressions and understand each topic better. We’ll take ones that are the most frequent among the documents.
#
# ~~~Python
# from collections import Counter
# from nltk import ngrams
#
# def get_ngrams(text, n ):
#     n_grams = ngrams(word_tokenize(text), n)
#     return [' '.join(grams) for grams in n_grams]
#
# bigrams = []
# for article in all_texts:
#     bigrams += list(map(lambda x: x[0], list(filter(lambda x: x[1] >= 5,
#                                                     Counter(get_ngrams(article, 2)).most_common()))))
#
# bigrams = list(filter(lambda x: 'package' not in x and 'document' not in x, bigrams))
# bigrams = list(map(lambda x: x[0], (list(filter(lambda x: x[1] >= 5, Counter(bigrams).most_common())))))
#
# print(len(bigrams))
# print(bigrams[:5])
# ~~~

# %%
from collections import Counter
from nltk import ngrams

def get_ngrams(text, n ):
    n_grams = ngrams(word_tokenize(text), n)
    return [' '.join(grams) for grams in n_grams]

# form vocabulary, find most common bigram to form vector space
bigrams = []
for article in all_texts:
    bigrams += list(map(lambda x: x[0], list(filter(lambda x: x[1] >= 5,
                                                    Counter(get_ngrams(article, 2)).most_common()))))

bigrams = list(filter(lambda x: 'package' not in x and 'document' not in x, bigrams))
bigrams = list(map(lambda x: x[0], (list(filter(lambda x: x[1] >= 5, Counter(bigrams).most_common())))))

print(len(bigrams))
print(bigrams[:5])
# Out:
# 442
# ['machine learning', 'neural network', 'information processing', 'neural information', 'arxiv preprint']

# %% [markdown]
# ## ARTM model
# All preprocessing has been done so we can move to our model. To do this, we have to create a matrix with words over documents which the model uses as an input.
#
# ~~~Python
# import numpy as np
# from sklearn.feature_extraction.text import CountVectorizer
#
# n_wd_bigrams = np.empty((len(bigrams), len(all_texts)))
#
# for i in range(len(bigrams)):
#     for j in range(len(all_texts)):
#         n_wd_bigrams[i][j] = all_texts[j].count(bigrams[i])
#
# cv = CountVectorizer(max_features = 1000, stop_words='english')
# n_wd = np.array(cv.fit_transform(all_texts).todense()).T
# vocabulary = cv.get_feature_names_out()
#
# vocabulary = list(vocabulary)
# vocabulary.extend(bigrams)
# ~~~

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer

n_wd_bigrams = np.empty((len(bigrams), len(all_texts)))

for i in range(len(bigrams)):
    for j in range(len(all_texts)):
        n_wd_bigrams[i][j] = all_texts[j].count(bigrams[i])

# from vocabulary to form features
cv = CountVectorizer(max_features = 1000, stop_words='english')
n_wd = np.array(cv.fit_transform(all_texts).todense()).T
vocabulary = cv.get_feature_names_out()

vocabulary = list(vocabulary)
vocabulary.extend(bigrams)

# %%
vocabulary

# %% [markdown]
# ARTM library provides you with a huge functionality to affect the learning process. It allows adding various regularizers to control the learning process and to change phi and theta matrices to be more sparse, for example. In a top level model I added a sparsity regularizer for theta matrix and decorrelator which stimulates phi sparsity.
#
# Besides, we can specify metrics that we want to use for evaluation (Here there are Perxplexity and matrices sparstities). We add these regularizers to make topics more interpretable but we have to do that carefully with only a slight decrease of perplexity.
#
# ~~~Python
# import artm
#
# bv = artm.BatchVectorizer(data_format='bow_n_wd', n_wd=n_wd, vocabulary=vocabulary)
# dictionary = bv.dictionary
# topic_names = ['topic_{}'.format(i) for i in range(10)]
#
# model_artm = artm.ARTM(topic_names = topic_names, cache_theta=True,
#                        scores=[artm.PerplexityScore(name='PerplexityScore', dictionary=dictionary),
#                                artm.SparsityPhiScore(name='SparsityPhiScore'),
#                                artm.SparsityThetaScore(name='SparsityThetaScore'),
#                                artm.TopicKernelScore(name='TopicKernelScore',probability_mass_threshold=0.3),
#                                artm.TopTokensScore(name='TopTokensScore', num_tokens=8)],
#                        regularizers=[artm.SmoothSparseThetaRegularizer(name='SparseTheta', tau=-0.4),
#                                      artm.DecorrelatorPhiRegularizer(name='DecorrelatorPhi', tau=2.5e+5)])
#
# model_artm.num_document_passes = 4
# model_artm.initialize(dictionary)
# model_artm.fit_offline(batch_vectorizer=bv, num_collection_passes=20)
# ~~~

# %%
import artm

bv = artm.BatchVectorizer(data_format='bow_n_wd', n_wd=n_wd, vocabulary=vocabulary)
dictionary = bv.dictionary
topic_names = ['topic_{}'.format(i) for i in range(10)]

# 5 evaluation matrix
model_artm = artm.ARTM(topic_names = topic_names, cache_theta=True,
                       scores=[artm.PerplexityScore(name='PerplexityScore', dictionary=dictionary),
                               artm.SparsityPhiScore(name='SparsityPhiScore'),
                               artm.SparsityThetaScore(name='SparsityThetaScore'),
                               artm.TopicKernelScore(name='TopicKernelScore',probability_mass_threshold=0.3),
                               artm.TopTokensScore(name='TopTokensScore', num_tokens=8)],
                       regularizers=[artm.SmoothSparseThetaRegularizer(name='SparseTheta', tau=-0.4),
                                     artm.DecorrelatorPhiRegularizer(name='DecorrelatorPhi', tau=2.5e+5)])

model_artm.num_document_passes = 4
model_artm.initialize(dictionary)
model_artm.fit_offline(batch_vectorizer=bv, num_collection_passes=20)
# Out:
# /usr/local/lib/python3.10/dist-packages/artm/batches_utils.py:227: DeprecationWarning: Please use `spmatrix` from the `scipy.sparse` namespace, the `scipy.sparse.base` namespace is deprecated.
#   from scipy.sparse.base import spmatrix

# %% [markdown]
# ## Model Quality
# The ARTM model quality is assessed using the following measures:
# 1. **Perplexity**: This is inversely proportional to the likelihood of the data given the model. The smaller the perplexity the better the model.
# 2. **Sparsity**: This measures the percentage of elements that are zero in the ∅ and θ matrices.
# 3. **Ratio of background words**: A high ratio of background words indicates model degradation and is a good stopping criterion. This could be due to too much sparsing or elimination of topics.
# 4. **Coherence**: This is used to measure the interpretability of a model. A topic is supposed to be coherent, if the most frequent words in a topic tend to appear together in the documents.
# 5. **Kernel size, purity and contrast**: A kernel is defined as the subset of words in a topic that separates a topic from the others. For a topic model, higher values are better for both purity and contrast.
#
#
# Let's look at the main measures:
#
# ~~~Python
# import matplotlib.pyplot as plt
#
# def print_measures(model_artm):
#     print('Sparsity Phi ARTM:{}'.format(model_artm.score_tracker['SparsityPhiScore'].last_value))
#     print('Sparsity Theta ARTM:{}'.format(model_artm.score_tracker['SparsityThetaScore'].last_value))
#     print('Perplexity ARTM: {}'.format(model_artm.score_tracker['PerplexityScore'].last_value))
#
#     fig, axs = plt.subplots(1, 3, figsize = (30, 5))
#
#     for idx, score, y_label in zip(range(3), ['PerplexityScore', 'SparsityPhiScore', 'SparsityThetaScore'],
#                                              ['ARTM perplexity', 'ARTM Phi sparsity', 'ARTM Theta sparsity']):
#         axs[idx].plot(range(model_artm.num_phi_updates), model_artm.score_tracker[score].value, 'r--', linewidth=2)
#         axs[idx].set_xlabel('Iterations count')
#         axs[idx].set_ylabel(y_label)
#         axs[idx].grid(True)
#
# print_measures(model_artm)
# ~~~

# %%
import matplotlib.pyplot as plt

def print_measures(model_artm):
    print('Sparsity Phi ARTM:{}'.format(model_artm.score_tracker['SparsityPhiScore'].last_value))
    print('Sparsity Theta ARTM:{}'.format(model_artm.score_tracker['SparsityThetaScore'].last_value))
    print('Perplexity ARTM: {}'.format(model_artm.score_tracker['PerplexityScore'].last_value))

    fig, axs = plt.subplots(1, 3, figsize = (30, 5))

    for idx, score, y_label in zip(range(3), ['PerplexityScore', 'SparsityPhiScore', 'SparsityThetaScore'],
                                             ['ARTM perplexity', 'ARTM Phi sparsity', 'ARTM Theta sparsity']):
        axs[idx].plot(range(model_artm.num_phi_updates), model_artm.score_tracker[score].value, 'r--', linewidth=2)
        axs[idx].set_xlabel('Iterations count')
        axs[idx].set_ylabel(y_label)
        axs[idx].grid(True)

print_measures(model_artm)
# first graph: star stagnating after 2.5
# Out:
# Sparsity Phi ARTM:0.002300000051036477
# Sparsity Theta ARTM:0.0
# Perplexity ARTM: 516.7318725585938

# %% [markdown]
# Let's look at the topics that we have obtained:
#
# ~~~Python
# for topic_name in model_artm.topic_names:
#     print(topic_name + ': ' +  str(model_artm.score_tracker['TopTokensScore'].last_tokens[topic_name]))
# ~~~

# %%
for topic_name in model_artm.topic_names:
    print(topic_name + ': ' +  str(model_artm.score_tracker['TopTokensScore'].last_tokens[topic_name]))
# infer what does topic 1 mean
# Out:
# topic_0: ['algorithm', 'set', 'graph', 'function', 'node', 'problem', 'let', 'bound']
# topic_1: ['matrix', 'vector', 'sparse', 'norm', 'problem', 'group', 'rank', 'value']
# topic_2: ['network', 'neural', 'layer', 'training', 'deep', 'weight', 'architecture', 'use']
# topic_3: ['policy', 'state', 'reward', 'action', 'regret', 'agent', 'game', 'value']
# topic_4: ['model', 'time', 'variable', 'inference', 'latent', 'using', 'process', 'approach']
# topic_5: ['learning', 'task', 'loss', 'training', 'label', 'example', 'domain', 'using']
# topic_6: ['image', 'feature', 'object', 'map', 'input', 'representation', 'convolutional', 'recognition']
# topic_7: ['sample', 'distribution', 'kernel', 'function', 'log', 'gaussian', 'variational', 'posterior']
# topic_8: ['gradient', 'bound', 'convergence', 'function', 'convex', 'theorem', 'error', 'stochastic']
# topic_9: ['problem', 'cost', 'set', 'optimization', 'constraint', 'point', 'rate', 'rule']

# %% [markdown]
# ## Building hierarchy
# The topics that we have got seem rather vague, although we can see differences between them. If we are interested in a particular topic, we might want to look at the subtopics of this one and to narrow down the search area. For such purposes, we can build a hierarchy of models that looks like a tree. We will use only one additional level with 50 topics.
# ![topic_hierarchy.png](data:image/png;base64,...)
#
# ~~~Python
# topic_names = ['topic_{}'.format(i) for i in range(20)]
#
# model_artm1 = artm.ARTM(topic_names=topic_names,cache_theta=True,
#                         scores=[artm.PerplexityScore(name='PerplexityScore', dictionary=dictionary),
#                                 artm.SparsityPhiScore(name='SparsityPhiScore'),
#                                 artm.SparsityThetaScore(name='SparsityThetaScore'),
#                                 artm.TopicKernelScore(name='TopicKernelScore',probability_mass_threshold=0.3),
#                                 artm.TopTokensScore(name='TopTokensScore',num_tokens=12)],
#                         regularizers=[artm.SmoothSparseThetaRegularizer(name='SparseTheta', tau=-0.4),
#                         artm.SmoothSparsePhiRegularizer(name='SparsePhi',tau=-0.25),
#                         artm.DecorrelatorPhiRegularizer(name='DecorrelatorPhi', tau=2.5e+5)], seed=243) #seed is required for heirarchy
#
# model_artm1.num_document_passes = 4
# model_artm1.set_parent_model(parent_model = model_artm, parent_model_weight = 0.75)
# model_artm1.initialize(dictionary)
#
# model_artm1.fit_offline(batch_vectorizer=bv, num_collection_passes=12)
#
# subt = pd.DataFrame(model_artm1.get_parent_psi())
# subt.columns = ['topic_{}'.format(i) for i in range(10)]
# subt.index = ['subtopic_{}'.format(i) for i in range(20)]
# subt.head()
# ~~~

# %%
topic_names = ['topic_{}'.format(i) for i in range(20)]

model_artm1 = artm.ARTM(topic_names=topic_names,cache_theta=True,
                        scores=[artm.PerplexityScore(name='PerplexityScore', dictionary=dictionary),
                                artm.SparsityPhiScore(name='SparsityPhiScore'),
                                artm.SparsityThetaScore(name='SparsityThetaScore'),
                                artm.TopicKernelScore(name='TopicKernelScore',probability_mass_threshold=0.3),
                                artm.TopTokensScore(name='TopTokensScore',num_tokens=12)],
                        regularizers=[artm.SmoothSparseThetaRegularizer(name='SparseTheta', tau=-0.4),
                        artm.SmoothSparsePhiRegularizer(name='SparsePhi',tau=-0.25),
                        artm.DecorrelatorPhiRegularizer(name='DecorrelatorPhi', tau=2.5e+5)], seed=243) #seed is required for heirarchy

model_artm1.num_document_passes = 4
model_artm1.set_parent_model(parent_model = model_artm, parent_model_weight = 0.75)
model_artm1.initialize(dictionary)

model_artm1.fit_offline(batch_vectorizer=bv, num_collection_passes=12)

subt = pd.DataFrame(model_artm1.get_parent_psi())
subt.columns = ['topic_{}'.format(i) for i in range(10)]
subt.index = ['subtopic_{}'.format(i) for i in range(20)]
subt.head(20)
# Out:
#               topic_0   topic_1   topic_2   topic_3   topic_4   topic_5  \
# subtopic_0   0.005457  0.002718  0.001353  0.005601  0.009982  0.010446
# subtopic_1   0.002037  0.003551  0.022029  0.000841  0.004661  0.007221
# subtopic_2   0.006864  0.281427  0.006882  0.006345  0.014028  0.005454
# subtopic_3   0.007131  0.014455  0.020090  0.010093  0.045117  0.012905
# subtopic_4   0.019047  0.018138  0.005102  0.023598  0.006878  0.008807
# subtopic_5   0.001127  0.002310  0.770828  0.001335  0.007758  0.013375
# subtopic_6   0.003608  0.005048  0.012306  0.006781  0.011458  0.362238
# subtopic_7   0.007212  0.480163  0.002011  0.002560  0.004824  0.001705
# subtopic_8   0.002996  0.004507  0.015839  0.006985  0.770464  0.004540
# subtopic_9   0.005168  0.003291  0.001914  0.773600  0.008301  0.003139
# subtopic_10  0.000519  0.001473  0.008398  0.001000  0.005688  0.008515
# subtopic_11  0.652960  0.012781  0.001117  0.020878  0.002035  0.002040
# subtopic_12  0.019277  0.015871  0.001778  0.014743  0.001296  0.003337
# subtopic_13  0.003235  0.003122  0.012689  0.028076  0.002999  0.464147
# subtopic_14  0.164934  0.019265  0.003639  0.022421  0.005132  0.010167
# subtopic_15  0.034760  0.035649  0.024408  0.027260  0.049352  0.017990
# subtopic_16  0.011592  0.030391  0.003744  0.012169  0.006599  0.006363
# subtopic_17  0.007255  0.017445  0.002559  0.009883  0.016796  0.003205
# subtopic_18  0.006241  0.013159  0.076402  0.010805  0.013884  0.037908
# subtopic_19  0.038579  0.035235  0.006912  0.015025  0.012748  0.016496
#
#               topic_6   topic_7   topic_8   topic_9
# subtopic_0   0.002640  0.530177  0.003186  0.004516
# subtopic_1   0.359259  0.002564  0.000479  0.007144
# subtopic_2   0.006157  0.006157  0.013060  0.016043
# subtopic_3   0.109603  0.009618  0.003841  0.018601
# subtopic_4   0.003710  0.008117  0.011336  0.426059
# subtopic_5   0.024428  0.001945  0.001476  0.002252
# subtopic_6   0.018711  0.005290  0.006126  0.012838
# subtopic_7   0.001770  0.004904  0.014104  0.004880
# subtopic_8   0.012792  0.008495  0.001063  0.003552
# subtopic_9   0.001237  0.002832  0.003908  0.008406
# subtopic_10  0.391936  0.002344  0.000399  0.002296
# subtopic_11  0.001145  0.003280  0.012427  0.023621
# subtopic_12  0.000531  0.009389  0.681697  0.014037
# subtopic_13  0.010676  0.007800  0.004394  0.008881
# subtopic_14  0.002117  0.022028  0.104558  0.016446
# subtopic_15  0.014382  0.010972  0.024154  0.036767
# subtopic_16  0.004672  0.013306  0.035113  0.246248
# subtopic_17  0.001063  0.287681  0.052839  0.004663
# subtopic_18  0.018708  0.046920  0.007248  0.028828
# subtopic_19  0.014462  0.016180  0.018593  0.113922

# %% [markdown]
# Let's look at the words in the subtopics:
#
# ~~~Python
# for topic_name in model_artm1.topic_names:
#     print(topic_name + ': ' +  str(model_artm1.score_tracker['TopTokensScore'].last_tokens[topic_name]))
# ~~~

# %%
for topic_name in model_artm1.topic_names:
    print(topic_name + ': ' +  str(model_artm1.score_tracker['TopTokensScore'].last_tokens[topic_name]))
# Out:
# topic_0: ['distribution', 'sample', 'generative', 'variational', 'posterior', 'sampling', 'density', 'gan', 'bayesian', 'process', 'function', 'generator']
# topic_1: ['feature', 'object', 'map', 'visual', 'convolutional', 'recognition', 'representation', 'input', 'decoder', 'detection', 'trained', 'face']
# topic_2: ['group', 'tensor', 'dimension', 'norm', 'parameter', 'estimation', 'linear', 'case', 'privacy', 'value', 'fairness', 'phase']
# topic_3: ['different', 'filter', 'field', 'proposed', 'scale', 'information', 'convolution', 'signal', 'prediction', 'produce', 'used', 'left']
# topic_4: ['problem', 'optimization', 'cost', 'constraint', 'solution', 'set', 'linear', 'space', 'prediction', 'rate', 'best', 'based']
# topic_5: ['network', 'neural', 'layer', 'deep', 'training', 'weight', 'architecture', 'arxiv', 'preprint', 'attention', 'parameter', 'output']
# topic_6: ['loss', 'label', 'domain', 'using', 'target', 'performance', 'task', 'machine', 'experiment', 'uncertainty', 'source', 'classification']
# topic_7: ['matrix', 'sparse', 'vector', 'rank', 'entry', 'spectral', 'norm', 'problem', 'coordinate', 'eigenvalue', 'column', 'approximation']
# topic_8: ['model', 'time', 'variable', 'latent', 'inference', 'process', 'neural', 'using', 'approach', 'dynamic', 'parameter', 'structure']
# topic_9: ['policy', 'state', 'reward', 'action', 'regret', 'agent', 'game', 'value', 'online', 'time', 'reinforcement', 'bandit']
# topic_10: ['image', 'human', 'prediction', 'frame', 'flow', 'translation', 'video', 'input', 'sentence', 'vision', 'pixel', 'different']
# topic_11: ['algorithm', 'graph', 'set', 'node', 'problem', 'clustering', 'function', 'let', 'edge', 'cluster', 'bound', 'page']
# topic_12: ['gradient', 'bound', 'convergence', 'convex', 'function', 'error', 'iteration', 'stochastic', 'descent', 'rate', 'optimal', 'theorem']
# topic_13: ['learning', 'task', 'training', 'example', 'page', 'distribution', 'function', 'different', 'space', 'new', 'machine', 'learn']
# topic_14: ['theorem', 'function', 'random', 'log', 'query', 'complexity', 'probability', 'work', 'case', 'upper', 'information', 'theoretical']
# topic_15: ['number', 'value', 'section', 'size', 'user', 'time', 'different', 'using', 'local', 'machine', 'memory', 'comparison']
# topic_16: ['point', 'rule', 'given', 'rate', 'set', 'step', 'scheme', 'optimization', 'problem', 'constraint', 'penalty', 'cost']
# topic_17: ['kernel', 'log', 'estimator', 'function', 'gaussian', 'estimate', 'stochastic', 'parameter', 'variance', 'gradient', 'estimation', 'statistic']
# topic_18: ['test', 'use', 'classifier', 'class', 'experiment', 'transformation', 'dataset', 'operator', 'datasets', 'negative', 'invariant', 'mnist']
# topic_19: ['case', 'set', 'metric', 'given', 'regression', 'work', 'linear', 'conference', 'tree', 'defined', 'obtained', 'property']

# %% [markdown]
# ## Get subtopic to topic
# We can look at the most related subtopics to a topic we are interested in.
#
# ~~~Python
# def subtopics_wrt_topic(topic_number, matrix_dist):
#    return matrix_dist.iloc[:, topic_number].sort_values(ascending = False)[:5]
#
# subtopics_wrt_topic(0, subt)
# ~~~

# %%
def subtopics_wrt_topic(topic_number, matrix_dist):
   return matrix_dist.iloc[:, topic_number].sort_values(ascending = False)[:5]

subtopics_wrt_topic(0, subt)
# Out:
# subtopic_11    0.652960
# subtopic_14    0.164934
# subtopic_19    0.038579
# subtopic_15    0.034760
# subtopic_12    0.019277
# Name: topic_0, dtype: float32

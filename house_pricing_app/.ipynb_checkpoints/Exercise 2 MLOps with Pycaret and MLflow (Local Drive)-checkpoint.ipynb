# %% [markdown]
# # MLOps con MLflow

# %% [markdown]
# #### Get data

# %%
import mlflow

# load the dataset from pycaret
from pycaret.datasets import get_data
data = get_data('diamond')
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %% [markdown]
# #### Preprocessing

# %%
# initialize setup
from pycaret.regression import *
s = setup(data, target = 'Price', 
          transform_target = True, 
          log_experiment = True, 
          #log_plots = True,
          experiment_name = 'diamond')
# Out:
# <style type="text/css">
# #T_13418_row10_col1, #T_13418_row16_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_13418">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13418_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_13418_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13418_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13418_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_13418_row0_col1" class="data row0 col1" >8055</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13418_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_13418_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_13418_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_13418_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_13418_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_13418_row3_col1" class="data row3 col1" >(6000, 8)</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_13418_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_13418_row4_col1" class="data row4 col1" >(6000, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_13418_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_13418_row5_col1" class="data row5 col1" >(4200, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_13418_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_13418_row6_col1" class="data row6 col1" >(1800, 29)</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_13418_row7_col0" class="data row7 col0" >Ordinal features</td>
#       <td id="T_13418_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_13418_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_13418_row8_col1" class="data row8 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_13418_row9_col0" class="data row9 col0" >Categorical features</td>
#       <td id="T_13418_row9_col1" class="data row9 col1" >6</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_13418_row10_col0" class="data row10 col0" >Preprocess</td>
#       <td id="T_13418_row10_col1" class="data row10 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_13418_row11_col0" class="data row11 col0" >Imputation type</td>
#       <td id="T_13418_row11_col1" class="data row11 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_13418_row12_col0" class="data row12 col0" >Numeric imputation</td>
#       <td id="T_13418_row12_col1" class="data row12 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_13418_row13_col0" class="data row13 col0" >Categorical imputation</td>
#       <td id="T_13418_row13_col1" class="data row13 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_13418_row14_col0" class="data row14 col0" >Maximum one-hot encoding</td>
#       <td id="T_13418_row14_col1" class="data row14 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_13418_row15_col0" class="data row15 col0" >Encoding method</td>
#       <td id="T_13418_row15_col1" class="data row15 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_13418_row16_col0" class="data row16 col0" >Transform target</td>
#       <td id="T_13418_row16_col1" class="data row16 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_13418_row17_col0" class="data row17 col0" >Transform target method</td>
#       <td id="T_13418_row17_col1" class="data row17 col1" >yeo-johnson</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_13418_row18_col0" class="data row18 col0" >Fold Generator</td>
#       <td id="T_13418_row18_col1" class="data row18 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_13418_row19_col0" class="data row19 col0" >Fold Number</td>
#       <td id="T_13418_row19_col1" class="data row19 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_13418_row20_col0" class="data row20 col0" >CPU Jobs</td>
#       <td id="T_13418_row20_col1" class="data row20 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_13418_row21_col0" class="data row21 col0" >Use GPU</td>
#       <td id="T_13418_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_13418_row22_col0" class="data row22 col0" >Log Experiment</td>
#       <td id="T_13418_row22_col1" class="data row22 col1" >MlflowLogger</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_13418_row23_col0" class="data row23 col0" >Experiment Name</td>
#       <td id="T_13418_row23_col1" class="data row23 col1" >diamond</td>
#     </tr>
#     <tr>
#       <th id="T_13418_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_13418_row24_col0" class="data row24 col0" >USI</td>
#       <td id="T_13418_row24_col1" class="data row24 col1" >5b22</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# #### Model Training

# %%
# compare all models
best = compare_models()
# Out:
# <style type="text/css">
# #T_4c492 th {
#   text-align: left;
# }
# #T_4c492_row0_col0, #T_4c492_row1_col0, #T_4c492_row1_col1, #T_4c492_row1_col2, #T_4c492_row1_col3, #T_4c492_row1_col4, #T_4c492_row1_col5, #T_4c492_row1_col6, #T_4c492_row2_col0, #T_4c492_row2_col1, #T_4c492_row2_col2, #T_4c492_row2_col3, #T_4c492_row2_col4, #T_4c492_row2_col5, #T_4c492_row2_col6, #T_4c492_row3_col0, #T_4c492_row3_col1, #T_4c492_row3_col2, #T_4c492_row3_col3, #T_4c492_row3_col4, #T_4c492_row3_col5, #T_4c492_row3_col6, #T_4c492_row4_col0, #T_4c492_row4_col1, #T_4c492_row4_col2, #T_4c492_row4_col3, #T_4c492_row4_col4, #T_4c492_row4_col5, #T_4c492_row4_col6, #T_4c492_row5_col0, #T_4c492_row5_col1, #T_4c492_row5_col2, #T_4c492_row5_col3, #T_4c492_row5_col4, #T_4c492_row5_col5, #T_4c492_row5_col6, #T_4c492_row6_col0, #T_4c492_row6_col1, #T_4c492_row6_col2, #T_4c492_row6_col3, #T_4c492_row6_col4, #T_4c492_row6_col5, #T_4c492_row6_col6, #T_4c492_row7_col0, #T_4c492_row7_col1, #T_4c492_row7_col2, #T_4c492_row7_col3, #T_4c492_row7_col4, #T_4c492_row7_col5, #T_4c492_row7_col6, #T_4c492_row8_col0, #T_4c492_row8_col1, #T_4c492_row8_col2, #T_4c492_row8_col3, #T_4c492_row8_col4, #T_4c492_row8_col5, #T_4c492_row8_col6, #T_4c492_row9_col0, #T_4c492_row9_col1, #T_4c492_row9_col2, #T_4c492_row9_col3, #T_4c492_row9_col4, #T_4c492_row9_col5, #T_4c492_row9_col6, #T_4c492_row10_col0, #T_4c492_row10_col1, #T_4c492_row10_col2, #T_4c492_row10_col3, #T_4c492_row10_col4, #T_4c492_row10_col5, #T_4c492_row10_col6, #T_4c492_row11_col0, #T_4c492_row11_col1, #T_4c492_row11_col2, #T_4c492_row11_col3, #T_4c492_row11_col4, #T_4c492_row11_col5, #T_4c492_row11_col6, #T_4c492_row12_col0, #T_4c492_row12_col1, #T_4c492_row12_col2, #T_4c492_row12_col3, #T_4c492_row12_col4, #T_4c492_row12_col5, #T_4c492_row12_col6, #T_4c492_row13_col0, #T_4c492_row13_col1, #T_4c492_row13_col2, #T_4c492_row13_col3, #T_4c492_row13_col4, #T_4c492_row13_col5, #T_4c492_row13_col6, #T_4c492_row14_col0, #T_4c492_row14_col1, #T_4c492_row14_col2, #T_4c492_row14_col3, #T_4c492_row14_col4, #T_4c492_row14_col5, #T_4c492_row14_col6, #T_4c492_row15_col0, #T_4c492_row15_col1, #T_4c492_row15_col2, #T_4c492_row15_col3, #T_4c492_row15_col4, #T_4c492_row15_col5, #T_4c492_row15_col6, #T_4c492_row16_col0, #T_4c492_row16_col1, #T_4c492_row16_col2, #T_4c492_row16_col3, #T_4c492_row16_col4, #T_4c492_row16_col5, #T_4c492_row16_col6, #T_4c492_row17_col0, #T_4c492_row17_col1, #T_4c492_row17_col2, #T_4c492_row17_col3, #T_4c492_row17_col4, #T_4c492_row17_col5, #T_4c492_row17_col6 {
#   text-align: left;
# }
# #T_4c492_row0_col1, #T_4c492_row0_col2, #T_4c492_row0_col3, #T_4c492_row0_col4, #T_4c492_row0_col5, #T_4c492_row0_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_4c492_row0_col7, #T_4c492_row1_col7, #T_4c492_row2_col7, #T_4c492_row3_col7, #T_4c492_row4_col7, #T_4c492_row5_col7, #T_4c492_row6_col7, #T_4c492_row7_col7, #T_4c492_row8_col7, #T_4c492_row10_col7, #T_4c492_row11_col7, #T_4c492_row12_col7, #T_4c492_row13_col7, #T_4c492_row14_col7, #T_4c492_row15_col7, #T_4c492_row16_col7, #T_4c492_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_4c492_row9_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_4c492">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c492_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4c492_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4c492_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4c492_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4c492_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4c492_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4c492_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_4c492_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c492_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_4c492_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_4c492_row0_col1" class="data row0 col1" >570.1389</td>
#       <td id="T_4c492_row0_col2" class="data row0 col2" >1314459.3542</td>
#       <td id="T_4c492_row0_col3" class="data row0 col3" >1128.7228</td>
#       <td id="T_4c492_row0_col4" class="data row0 col4" >0.9874</td>
#       <td id="T_4c492_row0_col5" class="data row0 col5" >0.0607</td>
#       <td id="T_4c492_row0_col6" class="data row0 col6" >0.0445</td>
#       <td id="T_4c492_row0_col7" class="data row0 col7" >0.1170</td>
#     </tr>
#     <tr>
#       <th id="T_4c492_level0_row1" class="row_heading level0 row1" >xgboost</th>
#       <td id="T_4c492_row1_col0" class="data row1 col0" >Extreme Gradient Boosting</td>
#       <td id="T_4c492_row1_col1" class="data row1 col1" >620.4010</td>
#       <td id="T_4c492_row1_col2" class="data row1 col2" >1496192.1109</td>
#       <td id="T_4c492_row1_col3" class="data row1 col3" >1206.9644</td>
#       <td id="T_4c492_row1_col4" class="data row1 col4" >0.9857</td>
#       <td id="T_4c492_row1_col5" class="data row1 col5" >0.0655</td>
#       <td id="T_4c492_row1_col6" class="data row1 col6" >0.0483</td>
#       <td id="T_4c492_row1_col7" class="data row1 col7" >0.0470</td>
#     </tr>
#     <tr>
#       <th id="T_4c492_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_4c492_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_4c492_row2_col1" class="data row2 col1" >623.1428</td>
#       <td id="T_4c492_row2_col2" class="data row2 col2" >1774144.6498</td>
#       <td id="T_4c492_row2_col3" class="data row2 col3" >1298.4015</td>
#       <td id="T_4c492_row2_col4" class="data row2 col4" >0.9830</td>
#       <td id="T_4c492_row2_col5" class="data row2 col5" >0.0660</td>
#       <td id="T_4c492_row2_col6" class="data row2 col6" >0.0480</td>
#       <td id="T_4c492_row2_col7" class="data row2 col7" >0.0250</td>
#     </tr>
#     <tr>
#       <th id="T_4c492_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_4c492_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_4c492_row3_col1" class="data row3 col1" >720.1557</td>
#       <td id="T_4c492_row3_col2" class="data row3 col2" >2260444.3188</td>
#       <td id="T_4c492_row3_col3" class="data row3 col3" >1456.8674</td>
#       <td id="T_4c492_row3_col4" class="data row3 col4" >0.9787</td>
#       <td id="T_4c492_row3_col5" class="data row3 col5" >0.0779</td>
#       <td id="T_4c492_row3_col6" class="data row3 col6" >0.0566</td>
#       <td id="T_4c492_row3_col7" class="data row3 col7" >0.1030</td>
#     </tr>
#     <tr>
#       <th id="T_4c492_level0_row4" class="row_heading level0 row4" >et</th>
#       <td id="T_4c492_row4_col0" class="data row4 col0" >Extra Trees Regressor</td>
#       <td id="T_4c492_row4_col1" class="data row4 col1" >743.1365</td>
#       <td id="T_4c492_row4_col2" class="data row4 col2" >2366160.7917</td>
#       <td id="T_4c492_row4_col3" class="data row4 col3" >1498.3771</td>
#       <td id="T_4c492_row4_col4" class="data row4 col4" >0.9777</td>
#       <td id="T_4c492_row4_col5" class="data row4 col5" >0.0807</td>
#       <td id="T_4c492_row4_col6" class="data row4 col6" >0.0585</td>
#       <td id="T_4c492_row4_col7" class="data row4 col7" >0.1260</td>
#     </tr>
#     <tr>
#       <th id="T_4c492_level0_row5" class="row_heading level0 row5" >gbr</th>
#       <td id="T_4c492_row5_col0" class="data row5 col0" >Gradient Boosting Regressor</td>
#       <td id="T_4c492_row5_col1" class="data row5 col1" >751.8482</td>
#       <td id="T_4c492_row5_col2" class="data row5 col2" >2458679.3448</td>
#       <td id="T_4c492_row5_col3" class="data row5 col3" >1538.9532</td>
#       <td id="T_4c492_row5_col4" class="data row5 col4" >0.9766</td>
#       <td id="T_4c492_row5_col5" class="data row5 col5" >0.0766</td>
#       <td id="T_4c492_row5_col6" class="data row5 col6" >0.0571</td>
#       <td id="T_4c492_row5_col7" class="

# %%
# check the residuals of trained model
plot_model(best, plot = 'residuals')

# %%
# check feature importance
plot_model(best, plot = 'feature')

# %%
# finalize the model
final_best = finalize_model(best)

# save model to disk
save_model(final_best, 'diamond-pipeline')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/var/folders/6h/1tyc70rx35d4nc_lnrd9xtpm0000gn/T/joblib),
#           steps=[('target_transformation',
#                   TransformerWrapperWithInverse(transformer=TargetTransformer(estimator=PowerTransformer(standardize=False)))),
#                  ('numerical_imputer',
#                   TransformerWrapper(include=['Carat Weight'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer'...
#                  ('onehot_encoding',
#                   TransformerWrapper(include=['Cut', 'Color', 'Clarity',
#                                               'Polish', 'Symmetry'],
#                                      transformer=OneHotEncoder(cols=['Cut',
#                                                                      'Color',
#                                                                      'Clarity',
#                                                                      'Polish',
#                                                                      'Symmetry'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('clean_column_names',
#                   TransformerWrapper(transformer=CleanColumnNames())),
#                  ('actual_estimator',
#                   <catboost.core.CatBoostRegressor object at 0x31b7f3700>)]),
#  'diamond-pipeline.pkl')

# %% [markdown]
# ### Model management with MLFlow

# %% [markdown]
# ### Consume the model

# %%
# alternative if you are saving your artifact locally

pipeline = load_model('diamond-pipeline')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %%
# print pipeline
print(pipeline)
# Out:
# Pipeline(memory=FastMemory(location=/var/folders/6h/1tyc70rx35d4nc_lnrd9xtpm0000gn/T/joblib),
#          steps=[('target_transformation',
#                  TransformerWrapperWithInverse(transformer=TargetTransformer(estimator=PowerTransformer(standardize=False)))),
#                 ('numerical_imputer',
#                  TransformerWrapper(include=['Carat Weight'],
#                                     transformer=SimpleImputer())),
#                 ('categorical_imputer'...
#                 ('onehot_encoding',
#                  TransformerWrapper(include=['Cut', 'Color', 'Clarity',
#                                              'Polish', 'Symmetry'],
#                                     transformer=OneHotEncoder(cols=['Cut',
#                                                                     'Color',
#                                                                     'Clarity',
#                                                                     'Polish',
#                                                                     'Symmetry'],
#                                                               handle_missing='return_nan',
#                                                               use_cat_names=True))),
#                 ('clean_column_names',
#                  TransformerWrapper(transformer=CleanColumnNames())),
#                 ('actual_estimator',
#                  <catboost.core.CatBoostRegressor object at 0x31b8ff340>)])

# %%
# create a copy of data and drop Price
data2 = data.copy()
data2.drop('Price', axis=1, inplace=True)

# %%
# generate predictions
from pycaret.regression import predict_model
predictions = predict_model(pipeline, data=data2)
predictions.head()
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  prediction_label
# 0          1.10  Ideal     H     SI1     VG       EX    GIA       5401.711908
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL       3527.984701
# 2          0.85  Ideal     H     SI1     EX       EX    GIA       3345.987776
# 3          0.91  Ideal     E     SI1     VG       VG    GIA       4505.403759
# 4          0.83  Ideal     G     SI1     EX       EX    GIA       3325.653171
